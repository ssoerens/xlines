# %%
from obspy.clients.fdsn import Client
client = Client("IRIS")

# %%
import matplotlib.pyplot as plt
import matplotlib.colorbar as colorbar
from cartopy.io.img_tiles import StamenTerrain

# %%
# inventory = client.get_stations(network="VU")
inventory = client.get_stations(minlatitude = -24, maxlatitude = -10, minlongitude = 155, maxlongitude = 180)

# %%
inventory.networks.remove(inventory[3])
inventory.networks.remove(inventory[3])
inventory
# Out:
# Inventory created at 2017-09-30T21:27:26.000000Z
# 	Created by: IRIS WEB SERVICE: fdsnws-station | version: 1.1.29
# 		    http://service.iris.edu/fdsnws/station/1/query?minlatitude=-24.0&ma...
# 	Sending institution: IRIS-DMC (IRIS-DMC)
# 	Contains:
# 		Networks (5):
# 			G
# 			II
# 			ND
# 			XT
# 			Z1
# 		Stations (33):
# 			G.DZM (Dzumac - New Caledonia, France)
# 			G.NOC (Noumea - New Caledonia, France)
# 			G.NOUC (Port Laguerre - New Caledonia, France)
# 			G.PVC (Port Vila - Efate island, Vanuatu)
# 			G.SANVU (Espiritu Santo, Vanuatu)
# 			II.MSVF (Monasavu, Fiji)
# 			ND.KOUNC (Koumac, New Caledonia)
# 			ND.LIFNC (Lifou, Loyalty Islands, New Caledonia)
# 			ND.MARNC (Mare, Loyalty islands, New Caledonia)
# 			ND.ONTNC (Ouen Toro, Noumea, New Caledonia)
# 			ND.OUENC (Ouen island, New Caledonia)
# 			ND.PINNC (Pines island, New Caledonia)
# 			ND.PLGNC (Port Laguerre, New Caledonia)
# 			ND.YATNC (Mamie plateau, Yate, New Caledonia)
# 			XT.DAWA (Dawasamu)
# ...

# %%
inventory.plot(projection="local")
plt.show()

# %%
from obspy import UTCDateTime
now = UTCDateTime.now()
day = 60*60*24

# %%
inventory
# Out:
# Network G (GEOSCOPE)
# 	Station Count: 2/56 (Selected/Total)
# 	1982-01-01T00:00:00.000000Z - 2500-12-31T23:59:59.000000Z
# 	Access: open
# 	Contains:
# 		Stations (2):
# 			G.PVC (Port Vila - Efate island, Vanuatu)
# 			G.SANVU (Espiritu Santo, Vanuatu)
# 		Channels (0):

# %%
st = client.get_waveforms("ND", "KOUNC", "*", "*", now - day, now)
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# <ipython-input-124-5d9990eb9fcb> in <module>()
# ----> 1 st = client.get_waveforms("ND", "KOUNC", "*", "*", now - day, now)
#
# /anaconda/envs/xlines/lib/python3.6/site-packages/obspy/clients/fdsn/client.py in get_waveforms(self, network, station, location, channel, starttime, endtime, quality, minimumlength, longestonly, filename, attach_response, **kwargs)
#     734         # Gzip not worth it for MiniSEED and most likely disabled for this
#     735         # route in any case.
# --> 736         data_stream = self._download(url, use_gzip=False)
#     737         data_stream.seek(0, 0)
#     738         if filename:
#
# /anaconda/envs/xlines/lib/python3.6/site-packages/obspy/clients/fdsn/client.py in _download(self, url, return_string, data, use_gzip)
# ...

# %%
st.plot()
